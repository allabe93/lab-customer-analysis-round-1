# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv("files_for_lab/csv_files/file1.csv")
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv("files_for_lab/csv_files/file2.csv")
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3 = pd.read_csv("files_for_lab/csv_files/file3.csv")
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df1 = df1.rename(columns={'ST':'STATE'})

# %%
df2 = df2.rename(columns={'ST':'STATE'})

# %%
df1.columns = df1.columns.str.upper()

# %%
df2.columns = df2.columns.str.upper()

# %%
df3.columns = df3.columns.str.upper()

# %%
df1 = df1[['CUSTOMER', 'GENDER', 'STATE', 'EDUCATION', 'INCOME', 'POLICY TYPE', 'CUSTOMER LIFETIME VALUE', 'MONTHLY PREMIUM AUTO', 'VEHICLE CLASS', 'NUMBER OF OPEN COMPLAINTS', 'TOTAL CLAIM AMOUNT']]

# %%
df2 = df2[['CUSTOMER', 'GENDER', 'STATE', 'EDUCATION', 'INCOME', 'POLICY TYPE', 'CUSTOMER LIFETIME VALUE', 'MONTHLY PREMIUM AUTO', 'VEHICLE CLASS', 'NUMBER OF OPEN COMPLAINTS', 'TOTAL CLAIM AMOUNT']]

# %%
df3 = df3[['CUSTOMER', 'GENDER', 'STATE', 'EDUCATION', 'INCOME', 'POLICY TYPE', 'CUSTOMER LIFETIME VALUE', 'MONTHLY PREMIUM AUTO', 'VEHICLE CLASS', 'NUMBER OF OPEN COMPLAINTS', 'TOTAL CLAIM AMOUNT']]

# %%
df1.columns
# Out:
# Index(['CUSTOMER', 'GENDER', 'STATE', 'EDUCATION', 'INCOME', 'POLICY TYPE',
#        'CUSTOMER LIFETIME VALUE', 'MONTHLY PREMIUM AUTO', 'VEHICLE CLASS',
#        'NUMBER OF OPEN COMPLAINTS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['CUSTOMER', 'GENDER', 'STATE', 'EDUCATION', 'INCOME', 'POLICY TYPE',
#        'CUSTOMER LIFETIME VALUE', 'MONTHLY PREMIUM AUTO', 'VEHICLE CLASS',
#        'NUMBER OF OPEN COMPLAINTS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['CUSTOMER', 'GENDER', 'STATE', 'EDUCATION', 'INCOME', 'POLICY TYPE',
#        'CUSTOMER LIFETIME VALUE', 'MONTHLY PREMIUM AUTO', 'VEHICLE CLASS',
#        'NUMBER OF OPEN COMPLAINTS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
data = pd.concat([df1, df2, df3])
data.columns = [columns_name.lower().replace(' ', '_') for columns_name in data.columns]
data
# Out:
#      customer gender       state             education   income  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#          policy_type customer_lifetime_value  monthly_premium_auto  \
# 0      Personal Auto                     NaN                1000.0
# ...

# %%
data.select_dtypes(np.number)
# Out:
#        income  monthly_premium_auto  total_claim_amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
data.select_dtypes(exclude=["number"])
# Out:
#      customer gender       state             education     policy_type  \
# 0     RB50392    NaN  Washington                Master   Personal Auto
# 1     QZ44356      F     Arizona              Bachelor   Personal Auto
# 2     AI49188      F      Nevada              Bachelor   Personal Auto
# 3     WW63253      M  California              Bachelor  Corporate Auto
# 4     GA49547      M  Washington  High School or Below   Personal Auto
# ...       ...    ...         ...                   ...             ...
# 7065  LA72316      M  California              Bachelor   Personal Auto
# 7066  PK87824      F  California               College  Corporate Auto
# 7067  TD14365      M  California              Bachelor  Corporate Auto
# 7068  UP19263      M  California               College   Personal Auto
# 7069  Y167826      M  California               College  Corporate Auto
#
#      customer_lifetime_value  vehicle_class number_of_open_complaints
# ...

# %%
del data['education'] 
del data['number_of_open_complaints']

# %%
display(data)
# Out:
#      customer gender       state   income     policy_type  \
# 0     RB50392    NaN  Washington      0.0   Personal Auto
# 1     QZ44356      F     Arizona      0.0   Personal Auto
# 2     AI49188      F      Nevada  48767.0   Personal Auto
# 3     WW63253      M  California      0.0  Corporate Auto
# 4     GA49547      M  Washington  36357.0   Personal Auto
# ...       ...    ...         ...      ...             ...
# 7065  LA72316      M  California  71941.0   Personal Auto
# 7066  PK87824      F  California  21604.0  Corporate Auto
# 7067  TD14365      M  California      0.0  Corporate Auto
# 7068  UP19263      M  California  21941.0   Personal Auto
# 7069  Y167826      M  California      0.0  Corporate Auto
#
#      customer_lifetime_value  monthly_premium_auto  vehicle_class  \
# 0                        NaN                1000.0  Four-Door Car
# 1                 697953.59%                  94.0  Four-Door Car
# 2                1288743.17%                 108.0   Two-Door Car
# ...

# %%
data.dtypes
# Out:
# customer                    object
# gender                      object
# state                       object
# income                     float64
# policy_type                 object
# customer_lifetime_value     object
# monthly_premium_auto       float64
# vehicle_class               object
# total_claim_amount         float64
# dtype: object

# %%
# I was able of removing the NaN´s in 'customer_lifetime_value', but I was not able to remove the % sign to proceed ->
# -> with the multiplication by 100 and change to numerical type.
# I tried a lot of different possible solutions. Please see what I have tested last below.
# I would appreciate some feedback on what I could have done. Thank you in advance!

# %%
data = data.dropna(subset=['customer_lifetime_value'])

# %%
display(data)
# Out:
#      customer gender       state   income     policy_type  \
# 1     QZ44356      F     Arizona      0.0   Personal Auto
# 2     AI49188      F      Nevada  48767.0   Personal Auto
# 3     WW63253      M  California      0.0  Corporate Auto
# 4     GA49547      M  Washington  36357.0   Personal Auto
# 5     OC83172      F      Oregon  62902.0   Personal Auto
# ...       ...    ...         ...      ...             ...
# 7065  LA72316      M  California  71941.0   Personal Auto
# 7066  PK87824      F  California  21604.0  Corporate Auto
# 7067  TD14365      M  California      0.0  Corporate Auto
# 7068  UP19263      M  California  21941.0   Personal Auto
# 7069  Y167826      M  California      0.0  Corporate Auto
#
#      customer_lifetime_value  monthly_premium_auto  vehicle_class  \
# 1                 697953.59%                  94.0  Four-Door Car
# 2                1288743.17%                 108.0   Two-Door Car
# 3                 764586.18%                 106.0            SUV
# ...

# %%
for i in data['customer_lifetime_value']:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
# With the below solution I removed the percentages, but was not able to create a list with the output

# %%
for value in data['customer_lifetime_value']:
    changed_value = str(value).replace('%', '')
    fixed_customer_lifetime_value = int(float(changed_value) * 100)
    print(fixed_customer_lifetime_value)
# Out:
# 69795359
# 128874317
# 76458618
# 53630765
# 82562978
# 53808986
# 72161003
# 241275040
# 73881781
# 47389920
# 81971971
# 87987970
# 88190189
# 53844317
# 74631394
# 25668678
# 39452416
# 57103331
# 81626171
# 28720513
# 61771093
# 241275040
# 24501910
# 23921079
# 58020660
# 39463721
# 91620632
# 129025601
# 32353605
# 24545835
# 189754561
# 47153213
# 47378717
# 49329163
# 57442297
# 138917357
# 73809767
# 30900340
# 25216331
# 26520618
# 27710450
# 39390064
# 122318797
# 49516561
# 128191029
# 44685105
# 55143440
# 33438753
# 22944789
# 367074264
# 334733495
# 79834317
# 48793848
# 42939973
# 71643955
# 76195158
# 39580028
# 44994933
# 40595674
# 44581134
# 81103331
# 33397649
# 242610177
# 66139737
# 29306934
# 86721943
# 116386693
# 68461503
# 117277764
# 226438348
# 26144743
# 24517527
# 67812702
# 49748015
# 85916049
# 55921614
# 80094728
# 581665535
# 80252294
# 57801822
# 41185391
# 25230702
# 65542164
# 53827519
# 59267293
# 26834707
# 26951824
# 60470252
# 131710128
# ...

# %%
my_list = [fixed_customer_lifetime_value]
my_list
# Out:
# [261183]

# %%
# With the below solution, the percentages are still there

# %%
for value in data['customer_lifetime_value']:
    if value is str:
        changed_value = value.replace("%", "")
        print(changed_value)
    else:
        print(value)
# Out:
# 697953.59%
# 1288743.17%
# 764586.18%
# 536307.65%
# 825629.78%
# 538089.86%
# 721610.03%
# 2412750.40%
# 738817.81%
# 473899.20%
# 819719.71%
# 879879.70%
# 881901.89%
# 538443.17%
# 746313.94%
# 256686.78%
# 394524.16%
# 571033.31%
# 816261.71%
# 287205.13%
# 617710.93%
# 2412750.40%
# 245019.10%
# 239210.79%
# 580206.60%
# 394637.21%
# 916206.32%
# 1290256.01%
# 323536.05%
# 245458.35%
# 1897545.61%
# 471532.13%
# 473787.17%
# 493291.63%
# 574422.97%
# 1389173.57%
# 738097.67%
# 309003.41%
# 252163.31%
# 265206.18%
# 277104.50%
# 393900.64%
# 1223187.97%
# 495165.61%
# 1281910.29%
# 446851.05%
# 551434.40%
# 334387.53%
# 229447.89%
# 3670742.64%
# 3347334.95%
# 798343.17%
# 487938.48%
# 429399.73%
# 716439.55%
# 761951.58%
# 395800.28%
# 449949.33%
# 405956.74%
# 445811.34%
# 811033.31%
# 333976.49%
# 2426101.78%
# 661397.37%
# 293069.35%
# 867219.43%
# 1163866.93%
# 684615.03%
# 1172777.65%
# 2264383.48%
# 261447.43%
# 245175.27%
# 678127.02%
# 497480.15%
# 859160.49%
# ...

# %%
print(value)
# Out:
# 2611.836866

# %%
changed_value.str.replace('%', '')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 changed_value.str.replace('%', '')
#
# AttributeError: 'str' object has no attribute 'str'

# %%
# I would appreciate feedback to solve the above situation!

# %%
data.duplicated()
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 9130, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 3

# %%
data.loc[data.duplicated(), :]
# Out:
#   customer gender       state   income    policy_type customer_lifetime_value  \
# 0  GS98873      F     Arizona  16061.0  Personal Auto              323912.47%
# 1  CW49887      F  California  79487.0   Special Auto              462680.11%
# 2  MY31220      F  California  54230.0  Personal Auto              899704.02%
#
#    monthly_premium_auto  vehicle_class  total_claim_amount
# 0                  88.0  Four-Door Car               633.6
# 1                 114.0            SUV               547.2
# 2                 112.0   Two-Door Car               537.6

# %%
data.drop_duplicates()
# Out:
#      customer gender       state   income     policy_type  \
# 1     QZ44356      F     Arizona      0.0   Personal Auto
# 2     AI49188      F      Nevada  48767.0   Personal Auto
# 3     WW63253      M  California      0.0  Corporate Auto
# 4     GA49547      M  Washington  36357.0   Personal Auto
# 5     OC83172      F      Oregon  62902.0   Personal Auto
# ...       ...    ...         ...      ...             ...
# 7065  LA72316      M  California  71941.0   Personal Auto
# 7066  PK87824      F  California  21604.0  Corporate Auto
# 7067  TD14365      M  California      0.0  Corporate Auto
# 7068  UP19263      M  California  21941.0   Personal Auto
# 7069  Y167826      M  California      0.0  Corporate Auto
#
#      customer_lifetime_value  monthly_premium_auto  vehicle_class  \
# 1                 697953.59%                  94.0  Four-Door Car
# 2                1288743.17%                 108.0   Two-Door Car
# 3                 764586.18%                 106.0            SUV
# ...

# %%
data[data['income'] <= 0]
# Out:
#      customer gender       state  income     policy_type  \
# 1     QZ44356      F     Arizona     0.0   Personal Auto
# 3     WW63253      M  California     0.0  Corporate Auto
# 7     CF85061      M     Arizona     0.0  Corporate Auto
# 10    SX51350      M  California     0.0   Personal Auto
# 11    VQ65197    NaN  California     0.0   Personal Auto
# ...       ...    ...         ...     ...             ...
# 7059  WZ45103      F  California     0.0   Personal Auto
# 7061  RX91025      M  California     0.0   Personal Auto
# 7062  AC13887      M  California     0.0  Corporate Auto
# 7067  TD14365      M  California     0.0  Corporate Auto
# 7069  Y167826      M  California     0.0  Corporate Auto
#
#      customer_lifetime_value  monthly_premium_auto  vehicle_class  \
# 1                 697953.59%                  94.0  Four-Door Car
# 3                 764586.18%                 106.0            SUV
# 7                 721610.03%                 101.0  Four-Door Car
# ...

# %%
data[(data.income != 0)]
# Out:
#      customer gender       state   income     policy_type  \
# 2     AI49188      F      Nevada  48767.0   Personal Auto
# 4     GA49547      M  Washington  36357.0   Personal Auto
# 5     OC83172      F      Oregon  62902.0   Personal Auto
# 6     XZ87318      F      Oregon  55350.0  Corporate Auto
# 8     DY87989      M      Oregon  14072.0  Corporate Auto
# ...       ...    ...         ...      ...             ...
# 7063  TF56202      M  California  66367.0   Personal Auto
# 7064  YM19146      F  California  47761.0   Personal Auto
# 7065  LA72316      M  California  71941.0   Personal Auto
# 7066  PK87824      F  California  21604.0  Corporate Auto
# 7068  UP19263      M  California  21941.0   Personal Auto
#
#      customer_lifetime_value  monthly_premium_auto  vehicle_class  \
# 2                1288743.17%                 108.0   Two-Door Car
# 4                 536307.65%                  68.0  Four-Door Car
# 5                 825629.78%                  69.0   Two-Door Car
# ...
